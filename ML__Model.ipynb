# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Importing and Reading the Combined Data

# %%
df = pd.read_csv('C:/Users/SS/OneDrive/Desktop/data/combined.csv')
df
# Out:
#         latitude   longitude blk_no            road_name  postal_code
# 0       1.375097  103.837619    174  ANG MO KIO AVENUE 4       560174  \
# 1       1.375097  103.837619    174  ANG MO KIO AVENUE 4       560174
# 2       1.375097  103.837619    174  ANG MO KIO AVENUE 4       560174
# 3       1.375097  103.837619    174  ANG MO KIO AVENUE 4       560174
# 4       1.375097  103.837619    174  ANG MO KIO AVENUE 4       560174
# ...          ...         ...    ...                  ...          ...
# 203501  1.384537  103.880589   999B    BUANGKOK CRESCENT       532999
# 203502  1.384537  103.880589   999B    BUANGKOK CRESCENT       532999
# 203503  1.384537  103.880589   999B    BUANGKOK CRESCENT       532999
# 203504  1.413597  103.898121   325A          SUMANG WALK       821325
# 203505  1.333504  103.855238    261       TOA PAYOH EAST       310261
#
#                      address      cbd_dist  min_dist_mrt    month        town
# 0       174 ANG MO KIO AVE 4  10296.855747   1096.947897  2015-01  ANG MO KIO  \
# 1       174 ANG MO KIO AVE 4  10296.855747   1096.947897  2015-12  ANG MO KIO
# 2       174 ANG MO KIO AVE 4  10296.855747   1096.947897  2016-05  ANG MO KIO
# 3       174 ANG MO KIO AVE 4  10296.855747   1096.947897  2016-06  ANG MO KIO
# 4       174 ANG MO KIO AVE 4  10296.855747   1096.947897  2016-11  ANG MO KIO
# ...                      ...           ...           ...      ...         ...
# 203501    999B BUANGKOK CRES  11691.013117   1406.968262  2023-11     HOUGANG
# 203502    999B BUANGKOK CRES  11691.013117   1406.968262  2023-11     HOUGANG
# 203503    999B BUANGKOK CRES  11691.013117   1406.968262  2023-11     HOUGANG
# 203504      325A SUMANG WALK  15352.044388   1348.497448  2023-11     PUNGGOL
# 203505    261 TOA PAYOH EAST   5601.626691    858.420927  2023-11   TOA PAYOH
#
#        flat_type block       street_name storey_range  floor_area_sqm
# 0         3 ROOM   174  ANG MO KIO AVE 4     07 TO 09            60.0  \
# 1         3 ROOM   174  ANG MO KIO AVE 4     10 TO 12            60.0
# 2         3 ROOM   174  ANG MO KIO AVE 4     04 TO 06            69.0
# 3         2 ROOM   174  ANG MO KIO AVE 4     07 TO 09            45.0
# 4         3 ROOM   174  ANG MO KIO AVE 4     04 TO 06            61.0
# ...          ...   ...               ...          ...             ...
# 203501    4 ROOM  999B     BUANGKOK CRES     01 TO 03            93.0
# 203502    4 ROOM  999B     BUANGKOK CRES     07 TO 09            93.0
# 203503    4 ROOM  999B     BUANGKOK CRES     10 TO 12            94.0
# 203504    3 ROOM  325A       SUMANG WALK     01 TO 03            68.0
# 203505    4 ROOM   261    TOA PAYOH EAST     07 TO 09            93.0
#
#                flat_model  lease_commence_date  resale_price
# 0                Improved                 1986      255000.0  \
# 1                Improved                 1986      275000.0
# 2                Improved                 1986      310000.0
# 3                Improved                 1986      253000.0
# 4                Improved                 1986      290000.0
# ...                   ...                  ...           ...
# 203501            Model A                 2019      558000.0
# 203502            Model A                 2019      575000.0
# 203503            Model A                 2019      625000.0
# 203504  Premium Apartment                 2020      455000.0
# 203505            Model A                 2019      950000.0
#
#            remaining_lease  lease_remain_years
# 0                       70                  62
# 1                       69                  62
# 2                       68                  62
# 3                       68                  62
# 4                       68                  62
# ...                    ...                 ...
# 203501  95 years 02 months                  95
# 203502  95 years 02 months                  95
# 203503   95 years 01 month                  95
# 203504  95 years 03 months                  96
# 203505  95 years 02 months                  95
#
# [203506 rows x 20 columns]

# %%
df.dtypes
# Out:
# latitude               float64
# longitude              float64
# blk_no                  object
# road_name               object
# postal_code              int64
# address                 object
# cbd_dist               float64
# min_dist_mrt           float64
# month                   object
# town                    object
# flat_type               object
# block                   object
# street_name             object
# storey_range            object
# floor_area_sqm         float64
# flat_model              object
# lease_commence_date      int64
# resale_price           float64
# remaining_lease         object
# lease_remain_years       int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# latitude               0
# longitude              0
# blk_no                 0
# road_name              0
# postal_code            0
# address                0
# cbd_dist               0
# min_dist_mrt           0
# month                  0
# town                   0
# flat_type              0
# block                  0
# street_name            0
# storey_range           0
# floor_area_sqm         0
# flat_model             0
# lease_commence_date    0
# resale_price           0
# remaining_lease        0
# lease_remain_years     0
# dtype: int64

# %% [markdown]
# ## Minor Data Preprocessing for Combined Data

# %%
import statistics

def get_median(x):
    split_list = x.split(' TO ')
    float_list = [float(i) for i in split_list]
    median = statistics.median(float_list)
    return median

df['storey_median'] = df['storey_range'].apply(lambda x: get_median(x))
df
# Out:
#         latitude   longitude blk_no            road_name  postal_code
# 0       1.375097  103.837619    174  ANG MO KIO AVENUE 4       560174  \
# 1       1.375097  103.837619    174  ANG MO KIO AVENUE 4       560174
# 2       1.375097  103.837619    174  ANG MO KIO AVENUE 4       560174
# 3       1.375097  103.837619    174  ANG MO KIO AVENUE 4       560174
# 4       1.375097  103.837619    174  ANG MO KIO AVENUE 4       560174
# ...          ...         ...    ...                  ...          ...
# 203501  1.384537  103.880589   999B    BUANGKOK CRESCENT       532999
# 203502  1.384537  103.880589   999B    BUANGKOK CRESCENT       532999
# 203503  1.384537  103.880589   999B    BUANGKOK CRESCENT       532999
# 203504  1.413597  103.898121   325A          SUMANG WALK       821325
# 203505  1.333504  103.855238    261       TOA PAYOH EAST       310261
#
#                      address      cbd_dist  min_dist_mrt    month        town
# 0       174 ANG MO KIO AVE 4  10296.855747   1096.947897  2015-01  ANG MO KIO  \
# 1       174 ANG MO KIO AVE 4  10296.855747   1096.947897  2015-12  ANG MO KIO
# 2       174 ANG MO KIO AVE 4  10296.855747   1096.947897  2016-05  ANG MO KIO
# 3       174 ANG MO KIO AVE 4  10296.855747   1096.947897  2016-06  ANG MO KIO
# 4       174 ANG MO KIO AVE 4  10296.855747   1096.947897  2016-11  ANG MO KIO
# ...                      ...           ...           ...      ...         ...
# 203501    999B BUANGKOK CRES  11691.013117   1406.968262  2023-11     HOUGANG
# 203502    999B BUANGKOK CRES  11691.013117   1406.968262  2023-11     HOUGANG
# 203503    999B BUANGKOK CRES  11691.013117   1406.968262  2023-11     HOUGANG
# 203504      325A SUMANG WALK  15352.044388   1348.497448  2023-11     PUNGGOL
# 203505    261 TOA PAYOH EAST   5601.626691    858.420927  2023-11   TOA PAYOH
#
#         ... block       street_name storey_range floor_area_sqm
# 0       ...   174  ANG MO KIO AVE 4     07 TO 09           60.0  \
# 1       ...   174  ANG MO KIO AVE 4     10 TO 12           60.0
# 2       ...   174  ANG MO KIO AVE 4     04 TO 06           69.0
# 3       ...   174  ANG MO KIO AVE 4     07 TO 09           45.0
# 4       ...   174  ANG MO KIO AVE 4     04 TO 06           61.0
# ...     ...   ...               ...          ...            ...
# 203501  ...  999B     BUANGKOK CRES     01 TO 03           93.0
# 203502  ...  999B     BUANGKOK CRES     07 TO 09           93.0
# 203503  ...  999B     BUANGKOK CRES     10 TO 12           94.0
# 203504  ...  325A       SUMANG WALK     01 TO 03           68.0
# 203505  ...   261    TOA PAYOH EAST     07 TO 09           93.0
#
#                flat_model lease_commence_date  resale_price
# 0                Improved                1986      255000.0  \
# 1                Improved                1986      275000.0
# 2                Improved                1986      310000.0
# 3                Improved                1986      253000.0
# 4                Improved                1986      290000.0
# ...                   ...                 ...           ...
# 203501            Model A                2019      558000.0
# 203502            Model A                2019      575000.0
# 203503            Model A                2019      625000.0
# 203504  Premium Apartment                2020      455000.0
# 203505            Model A                2019      950000.0
#
#            remaining_lease lease_remain_years  storey_median
# 0                       70                 62            8.0
# 1                       69                 62           11.0
# 2                       68                 62            5.0
# 3                       68                 62            8.0
# 4                       68                 62            5.0
# ...                    ...                ...            ...
# 203501  95 years 02 months                 95            2.0
# 203502  95 years 02 months                 95            8.0
# 203503   95 years 01 month                 95           11.0
# 203504  95 years 03 months                 96            2.0
# 203505  95 years 02 months                 95            8.0
#
# [203506 rows x 21 columns]

# %%
scope_df = df[['cbd_dist','min_dist_mrt','floor_area_sqm','lease_remain_years','storey_median','resale_price']]
scope_df
# Out:
#             cbd_dist  min_dist_mrt  floor_area_sqm  lease_remain_years
# 0       10296.855747   1096.947897            60.0                  62  \
# 1       10296.855747   1096.947897            60.0                  62
# 2       10296.855747   1096.947897            69.0                  62
# 3       10296.855747   1096.947897            45.0                  62
# 4       10296.855747   1096.947897            61.0                  62
# ...              ...           ...             ...                 ...
# 203501  11691.013117   1406.968262            93.0                  95
# 203502  11691.013117   1406.968262            93.0                  95
# 203503  11691.013117   1406.968262            94.0                  95
# 203504  15352.044388   1348.497448            68.0                  96
# 203505   5601.626691    858.420927            93.0                  95
#
#         storey_median  resale_price
# 0                 8.0      255000.0
# 1                11.0      275000.0
# 2                 5.0      310000.0
# 3                 8.0      253000.0
# 4                 5.0      290000.0
# ...               ...           ...
# 203501            2.0      558000.0
# 203502            8.0      575000.0
# 203503           11.0      625000.0
# 203504            2.0      455000.0
# 203505            8.0      950000.0
#
# [203506 rows x 6 columns]

# %%
scope_df = scope_df.drop_duplicates()
scope_df
# Out:
#             cbd_dist  min_dist_mrt  floor_area_sqm  lease_remain_years
# 0       10296.855747   1096.947897            60.0                  62  \
# 1       10296.855747   1096.947897            60.0                  62
# 2       10296.855747   1096.947897            69.0                  62
# 3       10296.855747   1096.947897            45.0                  62
# 4       10296.855747   1096.947897            61.0                  62
# ...              ...           ...             ...                 ...
# 203501  11691.013117   1406.968262            93.0                  95
# 203502  11691.013117   1406.968262            93.0                  95
# 203503  11691.013117   1406.968262            94.0                  95
# 203504  15352.044388   1348.497448            68.0                  96
# 203505   5601.626691    858.420927            93.0                  95
#
#         storey_median  resale_price
# 0                 8.0      255000.0
# 1                11.0      275000.0
# 2                 5.0      310000.0
# 3                 8.0      253000.0
# 4                 5.0      290000.0
# ...               ...           ...
# 203501            2.0      558000.0
# 203502            8.0      575000.0
# 203503           11.0      625000.0
# 203504            2.0      455000.0
# 203505            8.0      950000.0
#
# [197208 rows x 6 columns]

# %% [markdown]
# ## Checking and Handling for Skewness in the data

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# List of columns(continuous variables) for finding skewness
col = ['cbd_dist','min_dist_mrt','floor_area_sqm','lease_remain_years','storey_median','resale_price']

for i in col:
    plt.figure(figsize=(8, 6))  
    sns.boxplot(data=df, x=i)
    plt.title(f'Boxplot of {i}')
    plt.xlabel(i)
    plt.show()

# %%
df1 = scope_df

# %%
# Apply a logarithmic transformation to the required columns only.
# One need to apply it and check, in some cases it will handle the skewness, and in other cases it might not have a great 
                                                                # effect on the data, so no need to apply for that columns
    
df1['floor_area_sqm'] = np.log(df1['floor_area_sqm'])
sns.boxplot(x='floor_area_sqm', data=df1)
plt.show()

df1['storey_median'] = np.log(df1['storey_median'])
sns.boxplot(x='storey_median', data=df1)
plt.show()

df1['resale_price'] = np.log(df1['resale_price'])
sns.boxplot(x='resale_price', data=df1)
plt.show()

# %%
df1.dtypes
# Out:
# cbd_dist              float64
# min_dist_mrt          float64
# floor_area_sqm        float64
# lease_remain_years      int64
# storey_median         float64
# resale_price          float64
# dtype: object

# %% [markdown]
# ## Visualization among different columns using Correlation Matrix

# %%
import seaborn as sns

corrMatrix = df1.corr()
plt.figure(figsize=(15, 10))
plt.title("Correlation Heatmap")
sns.heatmap(
    corrMatrix, 
    xticklabels=corrMatrix.columns,
    yticklabels=corrMatrix.columns,
    cmap='RdBu', 
    annot=True
)
# Out:
# <Axes: title={'center': 'Correlation Heatmap'}>

# %% [markdown]
# ## Encoding Data

# %%
from sklearn.preprocessing import StandardScaler

X=df1[['cbd_dist','min_dist_mrt','floor_area_sqm','lease_remain_years','storey_median']]
y=df1['resale_price']

# Normalizing the encoded data
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
test_dataframe = pd.DataFrame(X)
test_dataframe
# Out:
#                0         1         2         3         4
# 0      -0.485349  0.586003 -1.776246 -0.665458  0.212574
# 1      -0.485349  0.586003 -1.776246 -0.665458  0.655760
# 2      -0.485349  0.586003 -1.230250 -0.665458 -0.441522
# 3      -0.485349  0.586003 -2.900108 -0.665458  0.212574
# 4      -0.485349  0.586003 -1.711672 -0.665458 -0.441522
# ...          ...       ...       ...       ...       ...
# 197203 -0.168772  1.258446 -0.064154  1.782894 -1.716706
# 197204 -0.168772  1.258446 -0.064154  1.782894  0.212574
# 197205 -0.168772  1.258446 -0.022371  1.782894  0.655760
# 197206  0.662553  1.131621 -1.287282  1.857087 -1.716706
# 197207 -1.551513  0.068631 -0.064154  1.782894  0.212574
#
# [197208 rows x 5 columns]

# %% [markdown]
# ## Splitting the data for training and testing purposes

# %%
from sklearn.model_selection import train_test_split

# test and train split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %% [markdown]
# ### Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import GridSearchCV

# Decision Tree Regressor
dtr = DecisionTreeRegressor()

# hyperparameters
param_grid = {
    'max_depth': [2, 5, 10, 15, 20, 22],
    'min_samples_split': [2, 3, 4, 5],
    'min_samples_leaf': [2, 3, 4, 5, 6, 7, 8, 9, 10, 15, 20],
    'max_features': ['auto', 'sqrt', 'log2']
}

# gridsearchcv
grid_search = GridSearchCV(estimator=dtr, param_grid=param_grid, cv=5)
grid_search.fit(X_train, y_train)
print("Best hyperparameters:", grid_search.best_params_)
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)

# evalution metrics
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
print(" ")
print('Mean squared error:', mse)
print('Mean Absolute Error', mae)
print('Root Mean squared error:', rmse)
print(" ")
print('R-squared:', r2)
# Out:
# Best hyperparameters: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 5}
#
# Mean squared error: 0.01502758571123701
# Mean Absolute Error 0.09667911348078198
# Root Mean squared error: 0.12258705360370242
#
# R-squared: 0.8626096542443386

# %% [markdown]
# ## Testing Our Trained Model (Decision Tree Regressor)

# %%
new_sample = np.array([[8740, 999, np.log(44), 55, np.log(11)]])
new_sample = scaler.transform(new_sample[:, :5])
new_pred = best_model.predict(new_sample)[0]
np.exp(new_pred)
# Out:
# 256505.7115801661

# %%
# Saving the model
import pickle
with open('model.pkl', 'wb') as file:
    pickle.dump(best_model, file)
with open('scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)

# %%
from IPython.display import FileLink

FileLink('model.pkl', result_html_prefix="Click to download: ")
# Out:
# C:\Users\BALAVIGNESH S S\Downloads\model.pkl

# %%
FileLink('scaler.pkl', result_html_prefix="Click to download: ")
# Out:
# C:\Users\BALAVIGNESH S S\Downloads\scaler.pkl
